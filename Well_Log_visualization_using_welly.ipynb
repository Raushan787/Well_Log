# %%
#Importing libraries
# !pip install welly
import welly

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
well=welly.Well.from_las("15-9-19_SR_COMP_logdata.LAS")
type(well)
# Out:
# welly.well.Well

# %%
well
# Out:
# Well(uwi: '', name: '15/9-19', 7 curves: ['AC', 'CALI', 'DEN', 'GR', 'NEU', 'RDEP', 'RMED'])

# %%
well.header
# Out:
#    original_mnemonic mnemonic  unit                                value  \
# 0               VERS     VERS                                        2.0
# 1               WRAP     WRAP                                         NO
# 2               STRT     STRT     M                             102.1568
# 3               STOP     STOP     M                             4636.514
# 4               STEP     STEP     M                               0.1524
# 5               NULL     NULL                                    -999.25
# 6                FLD      FLD                                        Q15
# 7               WELL     WELL                                    15/9-19
# 8                WBN      WBN                                 15/9-19 SR
# 9               NATI     NATI                                        NOR
# 10              CTRY     CTRY                                        NOR
# 11              COMP     COMP                                    STATOIL
# ...

# %%
#Coverting into pandas dataframe
df=well.df()
df = df.reset_index()
df
# Out:
#                  DEPT             AC  CALI           DEN             GR  \
# 0     3550.0000000000            NaN   NaN           NaN            NaN
# 1     3550.1524000000            NaN   NaN           NaN            NaN
# 2     3550.3048000000            NaN   NaN           NaN            NaN
# 3     3550.4572000000            NaN   NaN           NaN            NaN
# 4     3550.6096000000            NaN   NaN           NaN            NaN
# ...               ...            ...   ...           ...            ...
# 6885  4599.2739999996  70.3111572177   6.0  2.5154874016  62.5552887143
# 6886  4599.4263999996  70.2706587929   6.0  2.5223010499  62.3762548562
# 6887  4599.5787999996  70.2530629920   6.0  2.5245572178  61.7619419969
# 6888  4599.7311999996  70.2571908137   6.0  2.5202629921  60.4128086656
# 6889  4599.8835999996  70.2685401574   6.0  2.5117553806  58.8896112898
#
#                 NEU          RDEP          RMED
# 0               NaN           NaN           NaN
# ...

# %%
well.count_curves()
# Out:
# 7

# %%
well.plot()

# %%
#Gammaray and Calipier log
tracks=["MD","GR","CALI"]
well.plot(tracks=tracks)

# %%
#Comibing resistivity log
track=[["RDEP","RMED"]]
well.plot(tracks=track)

# %%
well.unify_basis(start=3550,stop=4600)
tracks=["MD","GR","CALI","DEN",["AC","NEU"],["RDEP","RMED"]]
well.plot(tracks=tracks)

# %%
plt.style.use("classic")

# %%
well.plot(tracks=tracks)
